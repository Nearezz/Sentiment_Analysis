# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor


df = pd.read_csv("../data/tweets_vader_sentiment.csv")
df.head()
# Out:
#          Date                                              Tweet Stock Name  \
# 0  2021-09-30  I bought my first $AAPL stock in 2010. \n\nSin...       AAPL
# 1  2021-09-30  The media is really pushing hard for their big...       AAPL
# 2  2021-09-30  In 2020, Tim Cook, CEO of $AAPL, earned $265,0...       AAPL
# 3  2021-09-30  This thread is just a broad overview of the ba...       AAPL
# 4  2021-09-30  All about this trendline now on $AAPL, continu...       AAPL
#
#   Company Name        Open        High         Low  Close   Adj Close  \
# 0   Apple Inc.  143.660004  144.380005  141.279999  141.5  140.478485
# 1   Apple Inc.  143.660004  144.380005  141.279999  141.5  140.478485
# 2   Apple Inc.  143.660004  144.380005  141.279999  141.5  140.478485
# 3   Apple Inc.  143.660004  144.380005  141.279999  141.5  140.478485
# 4   Apple Inc.  143.660004  144.380005  141.279999  141.5  140.478485
#
#        Volume                                         clean_text  vader_score  \
# 0  89056700.0  bought first aapl stock 2010 since seen 137229...       0.3182
# 1  89056700.0  media really pushing hard big money clients ts...       0.1585
# 2  89056700.0  2020 tim cook ceo aapl earned 265000000 total ...       0.0000
# 3  89056700.0  thread broad overview balance sheet want speci...       0.4767
# 4  89056700.0                   trendline aapl continuing reject      -0.4019
#
#    vader_label
# 0            1
# 1            1
# 2            0
# 3            1
# 4           -1

# %%
df['Date'] = pd.to_datetime(df['Date'])

price_df = df[['Stock Name','Date','Close']].drop_duplicates()

price_df = price_df.sort_values(['Stock Name','Date']).reset_index(drop=True)

price_df.head()


price_df['next_close'] = price_df.groupby('Stock Name')['Close'].shift(-1)

price_df['next_return'] = (price_df['next_close'] - price_df['Close']) / price_df['Close']

price_df.tail()

df = df.merge(
    price_df[['Stock Name', 'Date', 'next_close', 'next_return']],
    on=['Stock Name', 'Date'],
    how='left'
)

df[['Stock Name', 'Date', 'Close', 'next_close', 'next_return']].sample(10)
# Out:
#       Stock Name       Date       Close  next_close  next_return
# 31785       PYPL 2022-09-17         NaN         NaN          NaN
# 65191       TSLA 2022-08-10  294.356659  286.630005    -0.026249
# 15119         KO 2022-05-19   60.000000   60.980000     0.016333
# 26285        NIO 2022-06-17   20.770000         NaN          NaN
# 6800         AMD 2022-06-18         NaN         NaN          NaN
# 21037       MSFT 2022-06-06  268.750000  272.500000     0.013953
# 53606       TSLA 2022-04-13  340.790009  328.333344    -0.036552
# 40164       TSLA 2021-12-06  336.336670  350.583344     0.042358
# 70797        TSM 2021-11-15  118.120003  118.080002    -0.000339
# 68066       TSLA 2022-09-14  302.609985  303.750000     0.003767

# %%
df['log_volume'] = np.log1p(df['Volume'])

df[['Volume','log_volume']].head()


df['abs_vader'] = df['vader_score'].abs()

df[['vader_score', 'abs_vader']].head()
# Out:
#    vader_score  abs_vader
# 0       0.3182     0.3182
# 1       0.1585     0.1585
# 2       0.0000     0.0000
# 3       0.4767     0.4767
# 4      -0.4019     0.4019

# %%
# --- Feature engineering ---


df['tweet_length'] = df['clean_text'].apply(
    lambda x: len(str(x).split())
)


df['day_of_week'] = df['Date'].dt.dayofweek

df[['clean_text', 'tweet_length', 'day_of_week', 'vader_score']].head()
# Out:
#                                           clean_text  tweet_length  \
# 0  bought first aapl stock 2010 since seen 137229...            12
# 1  media really pushing hard big money clients ts...            29
# 2  2020 tim cook ceo aapl earned 265000000 total ...            26
# 3  thread broad overview balance sheet want speci...            21
# 4                   trendline aapl continuing reject             4
#
#    day_of_week  vader_score
# 0            3       0.3182
# 1            3       0.1585
# 2            3       0.0000
# 3            3       0.4767
# 4            3      -0.4019
